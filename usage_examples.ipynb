# %% [markdown]
# # ieugwaspy: Brief overview
#
# This notebook provides some examples of how to use ```ieugwaspy``` to access data from the IEU GWAS database API.
#
# First import the ```ieugwaspy``` package and ```pandas``` for data handling

# %%
import ieugwaspy as igd
import pandas as pd

# %% [markdown]
# ## Exploring available studies
#
# We get the full data on studies using the ```igd.gwasinfo()``` function, passing no parameters (if you pass a list of study IDs this function will just return the data for that subset). We then use Pandas ```DataFrame.from_dict``` function to convert this to a Pandas DataFrame, reorientating the data appropriately to one study per row. Finally, we look at the top of the file.

# %%
data = igd.gwasinfo()
df = pd.DataFrame.from_dict(data, orient='index')
df.head()
# Out:
#                        note  access    year  mr  author consortium  \
# eqtl-a-ENSG00000261662   NA  public  2018.0   1  Vosa U         NA
# eqtl-a-ENSG00000160460   NA  public  2018.0   1  Vosa U         NA
# eqtl-a-ENSG00000205426   NA  public  2018.0   1  Vosa U         NA
# eqtl-a-ENSG00000003436   NA  public  2018.0   1  Vosa U         NA
# prot-a-7                 NA  public  2018.0   1  Sun BB         NA
#
#                                       sex  priority population unit  \
# eqtl-a-ENSG00000261662  Males and Females         0   European   NA
# eqtl-a-ENSG00000160460  Males and Females         0   European   NA
# eqtl-a-ENSG00000205426  Males and Females         0   European   NA
# eqtl-a-ENSG00000003436  Males and Females         0   European   NA
# prot-a-7                Males and Females         0   European   NA
#
#                         sample_size      nsnp                         trait  \
# eqtl-a-ENSG00000261662       5502.0     14407               ENSG00000261662
# eqtl-a-ENSG00000160460      29896.0     18645               ENSG00000160460
# eqtl-a-ENSG00000205426      31684.0     19133               ENSG00000205426
# eqtl-a-ENSG00000003436      31684.0     18041               ENSG00000003436
# prot-a-7                     3301.0  10534735  Tyrosine-protein kinase ABL1
#
#                                             id subcategory       category  \
# eqtl-a-ENSG00000261662  eqtl-a-ENSG00000261662          NA             NA
# eqtl-a-ENSG00000160460  eqtl-a-ENSG00000160460          NA             NA
# eqtl-a-ENSG00000205426  eqtl-a-ENSG00000205426          NA             NA
# eqtl-a-ENSG00000003436  eqtl-a-ENSG00000003436          NA             NA
# prot-a-7                              prot-a-7     Protein  Immune system
#
#                         ncase        pmid  ncontrol  sd
# eqtl-a-ENSG00000261662    NaN         NaN       NaN NaN
# eqtl-a-ENSG00000160460    NaN         NaN       NaN NaN
# eqtl-a-ENSG00000205426    NaN         NaN       NaN NaN
# eqtl-a-ENSG00000003436    NaN         NaN       NaN NaN
# prot-a-7                  NaN  29875488.0       NaN NaN

# %% [markdown]
# We can query the DataFrame for studies with Body mass data using standard Pandas syntax

# %%
bmistudies = df[df['trait'].str.contains("body", case=False) & df['trait'].str.contains("mass", case=False)]
bmistudies.head()
# Out:
#                                                                note  access  \
# ebi-a-GCST006368                                                 NA  public
# ukb-a-267                                                        NA  public
# ukb-b-19953       21001: Output from GWAS pipeline using Phesant...  public
# ukb-a-265                                                        NA  public
# ukb-a-266                                                        NA  public
#
#                     year  mr        author consortium                sex  \
# ebi-a-GCST006368  2018.0   1   Hoffmann TJ         NA                 NA
# ukb-a-267         2017.0   1         Neale  Neale Lab  Males and Females
# ukb-b-19953       2018.0   1  Ben Elsworth    MRC-IEU  Males and Females
# ukb-a-265         2017.0   1         Neale  Neale Lab  Males and Females
# ukb-a-266         2017.0   1         Neale  Neale Lab  Males and Females
#
#                   priority population unit  sample_size      nsnp  \
# ebi-a-GCST006368         0   European   NA     315347.0  27854527
# ukb-a-267                1   European   SD     331315.0  10894596
# ukb-b-19953              1   European   SD     461460.0   9851867
# ukb-a-265                1   European   SD     330762.0  10894596
# ukb-a-266                1   European   SD     331291.0  10894596
#
#                                      trait                id subcategory  \
# ebi-a-GCST006368           Body mass index  ebi-a-GCST006368          NA
# ukb-a-267            Whole body water mass         ukb-a-267          NA
# ukb-b-19953          Body mass index (BMI)       ukb-b-19953          NA
# ukb-a-265              Whole body fat mass         ukb-a-265          NA
# ukb-a-266         Whole body fat-free mass         ukb-a-266          NA
#
#                     category  ncase        pmid  ncontrol  sd
# ebi-a-GCST006368          NA    NaN  30108127.0       NaN NaN
# ukb-a-267                 NA    NaN         NaN       NaN NaN
# ukb-b-19953       Continuous    NaN         NaN       NaN NaN
# ukb-a-265                 NA    NaN         NaN       NaN NaN
# ukb-a-266                 NA    NaN         NaN       NaN NaN

# %% [markdown]
# ## Extract association data
#
# ### Get tophits for a single study
#
# Here we use one of the studies returned by the query for "Body mass" above

# %%
tophits = pd.DataFrame.from_dict(igd.tophits(["ukb-b-19953"])).sort_values(by='p', ascending=True)
tophits.head()
# Out:
#                  p        se       n      beta   position chr           id  \
# 443  1.599560e-291  0.002014  461460  0.073497   53806453  16  ukb-b-19953
# 271  2.301440e-118  0.002342  461460  0.054172   57829135  18  ukb-b-19953
# 284  4.499870e-100  0.002612  461460  0.055468     628504   2  ukb-b-19953
# 100   1.999860e-91  0.002443  461460  0.049529  177889025   1  ukb-b-19953
# 183   4.600450e-87  0.004609  461460 -0.091156     422144   2  ukb-b-19953
#
#            rsid ea nea       eaf                  trait
# 443  rs56094641  G   A  0.404564  Body mass index (BMI)
# 271   rs6567160  C   T  0.232714  Body mass index (BMI)
# 284   rs6744646  G   A  0.828299  Body mass index (BMI)
# 100    rs539515  C   A  0.204942  Body mass index (BMI)
# 183  rs62107261  C   T  0.048327  Body mass index (BMI)

# %% [markdown]
# ### Extract association data for a combination of studies and SNPs
#
# This allows us to extract a specific set of SNPs from a specific set of studies, both passed as Python lists.

# %%
assocs = pd.DataFrame.from_dict(igd.associations(["rs56094641","rs6567160","rs6744646"],
                                                 ["ieu-a-974","ieu-a-785","ukb-a-248"], 
                                                 proxies=1, 
                                                 r2=0.8, 
                                                 align_alleles=1, 
                                                 palindromes=1, 
                                                 maf_threshold=0.3)
                                                ).sort_values(by='p', ascending=True)
assocs.head()
# Out:
#          se  position              p chr      beta       n         id  \
# 6  0.002447  53806453  1.258930e-191  16  0.072289  336107  ukb-a-248
# 7  0.002834  57829135   2.541560e-75  18  0.052066  336107  ukb-a-248
# 0  0.004100  53821862   5.667610e-74  16  0.074000  171366  ieu-a-974
# 8  0.003187    628504   5.767660e-58   2  0.051158  336107  ukb-a-248
# 1  0.004600  57829135   5.082760e-34  18  0.056300  171875  ieu-a-974
#
#          rsid ea nea       eaf  target_snp   proxy_snp  proxy target_a1  \
# 6  rs56094641  G   A  0.403318  rs56094641  rs56094641  False      None
# 7   rs6567160  C   T  0.234055   rs6567160   rs6567160  False      None
# 0  rs56094641  G   A    0.4667  rs56094641   rs7201850   True         G
# 8   rs6744646  G   A  0.829019   rs6744646   rs6744646  False      None
# 1   rs6567160  C   T    0.2833   rs6567160   rs6567160  False      None
#
#   target_a2 proxy_a1 proxy_a2                  trait
# 6      None     None     None  Body mass index (BMI)
# 7      None     None     None  Body mass index (BMI)
# 0         A        T        C        Body mass index
# 8      None     None     None  Body mass index (BMI)
# 1      None     None     None        Body mass index

# %% [markdown]
# ## Run a PheWAS
#
# Extract results against all traits for one SNP from the BMI example above

# %%
phewas = pd.DataFrame.from_dict(igd.phewas(["rs56094641"])).sort_values(by='p', ascending=True)
phewas.head()
# Out:
#           n  position      beta chr              p        se           id  \
# 259  461460  53806453  0.073497  16  1.599560e-291  0.002014  ukb-b-19953
# 237  454884  53806453  0.073344  16  4.395420e-286  0.002029   ukb-b-2303
# 295  461632  53806453  0.060550  16  3.499450e-257  0.001768  ukb-b-11842
# 211  454893  53806453  0.060498  16  3.999450e-253  0.001780  ukb-b-12039
# 230  454718  53806453  0.047362  16  6.998420e-242  0.001426   ukb-b-4650
#
#            rsid ea nea       eaf                            trait
# 259  rs56094641  G   A  0.404564            Body mass index (BMI)
# 237  rs56094641  G   A  0.404637            Body mass index (BMI)
# 295  rs56094641  G   A  0.404568                           Weight
# 211  rs56094641  G   A  0.404637                           Weight
# 230  rs56094641  G   A  0.404698  Comparative body size at age 10

# %% [markdown]
# ## Convert chr:pos variant IDs to rsid
#
# This is just a helper function to convert variants in chromosome:position format to dbSNP rsids for queries against the database

# %%
variants = igd.variants_to_rsid(['10:44865737','7:105561135-105563135'])
print(variants)
# Out:
# ['rs7777', 'rs234']
